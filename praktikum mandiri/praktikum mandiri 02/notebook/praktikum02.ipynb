# %%
#Menghubungkan colab dengan Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Memanggil data set lewat Gdrive
path = "/content/drive/MyDrive/Kuliah/Semester 7/Machine Learning/Praktikum/praktikum mandiri/praktikum mandiri 02/data"

# %%
#Membaca file day.csv
import pandas as pd

df_day = pd.read_csv("/content/drive/MyDrive/Kuliah/Semester 7/Machine Learning/Praktikum/praktikum mandiri/praktikum mandiri 02/data/day.csv")
df_day
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
# Bagian: Membagi dataset
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split

# Membagi dataset menjadi Training (80%) dan Testing (20%)
train_df, test_df = train_test_split(df_day, test_size=0.2, random_state=42)

print("Jumlah total data :", len(df_day))
print("Jumlah data Training :", len(train_df))
print("Jumlah data Testing :", len(test_df))
# Out:
# Jumlah total data : 731
# Jumlah data Training : 584
# Jumlah data Testing : 147

# %%
# Membagi Training lagi menjadi Training (90%) dan Validation (10%)
train_df, val_df = train_test_split(train_df, test_size=0.1, random_state=42)

print("Jumlah data Training setelah split:", len(train_df))
print("Jumlah data Validation:", len(val_df))
# Out:
# Jumlah data Training setelah split: 525
# Jumlah data Validation: 59

# %%
# Data Testing: 20% dari total dataset
train_df, test_df = train_test_split(df_day, test_size=0.2, random_state=42)

print("Jumlah data Testing :", len(test_df))
# Out:
# Jumlah data Testing : 147

# %%
# Menampilkan jumlah data dan 5 baris data teratas untuk setiap set (Training, Validation, Testing)

print("===== Data Training =====")
print(f"Jumlah data: {len(train_df)}")
print(train_df.head().to_string(index=False))

print("\n===== Data Validation =====")
print(f"Jumlah data: {len(val_df)}")
print(val_df.head().to_string(index=False))

print("\n===== Data Testing =====")
print(f"Jumlah data: {len(test_df)}")
print(test_df.head().to_string(index=False))
# Out:
# ===== Data Training =====
# Jumlah data: 584
#  instant     dteday  season  yr  mnth  holiday  weekday  workingday  weathersit     temp    atemp      hum  windspeed  casual  registered  cnt
#      683 2012-11-13       4   1    11        0        2           1           2 0.343333 0.323225 0.662917   0.342046     327        3767 4094
#      251 2011-09-08       3   0     9        0        4           1           3 0.633913 0.555361 0.939565   0.192748     153        1689 1842
#      337 2011-12-03       4   0    12        0        6           0           1 0.299167 0.310604 0.612917   0.095783     706        2908 3614
#      261 2011-09-18       3   0     9        0        0           0           1 0.507500 0.490537 0.695000   0.178483    1353        2921 4274
#      544 2012-06-27       3   1     6        0        3           1           1 0.697500 0.640792 0.360000   0.271775    1077        6258 7335
#
# ===== Data Validation =====
# Jumlah data: 59
# ...
